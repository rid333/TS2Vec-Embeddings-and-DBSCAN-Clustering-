# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from ts2vec import TS2Vec
import hdbscan

# %%
df = pd.read_csv("./data.csv")

# %%
df.head()
# Out:
#    Time  Detak Jantung  Sensor Flex Kanan    Sensor Flex Kiri   Unnamed: 4  \
# 0  0:00             81                    3                  4         NaN
# 1  0:01             82                    3                  3         NaN
# 2  0:02             85                    4                  3         NaN
# 3  0:03             85                    5                  4         NaN
# 4  0:04             81                    5                  5         NaN
#
#   Unnamed: 5
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df = df.drop(["Unnamed: 4", "Unnamed: 5"], axis=1)
df.columns = df.columns.str.strip()

# %%
df.head()
# Out:
#    Time  Detak Jantung  Sensor Flex Kanan  Sensor Flex Kiri
# 0  0:00             81                  3                 4
# 1  0:01             82                  3                 3
# 2  0:02             85                  4                 3
# 3  0:03             85                  5                 4
# 4  0:04             81                  5                 5

# %%
df.plot(x="Time", y=["Detak Jantung", "Sensor Flex Kanan", "Sensor Flex Kiri"], kind="line", marker="o")

plt.grid(True)
plt.show()

# %%
df.describe()
# Out:
#         heart_rate   flex_right    flex_left
# count  1440.000000  1440.000000  1440.000000
# mean     77.420139    36.150000    23.068750
# std       9.311862    35.683728    30.096304
# min      52.000000     0.000000     0.000000
# 25%      70.000000     4.000000     0.000000
# 50%      78.000000    23.000000     8.000000
# 75%      85.000000    66.000000    41.000000
# max      96.000000   165.000000   124.000000

# %%
df = df.rename(columns={
    "Detak Jantung": "heart_rate",
    "Sensor Flex Kanan": "flex_right",
    "Sensor Flex Kiri": "flex_left"
})

# %%
df.to_csv('data_main.csv', index=False)
